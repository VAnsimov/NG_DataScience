# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть
#
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`
#
#
# ### Дополнительная часть (необязательная)
#
#
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
from requests import request
from bs4 import BeautifulSoup, ResultSet, Tag
import pandas
import time

# %%
def get_habr_preview_posts() -> ResultSet:
    index = 1
    results: ResultSet = []

    while True:
        response = request(
            method='GET',
            url='https://habr.com/ru/all/page{}/'.format(index)
        )
        soup = BeautifulSoup(response.text)
        posts = soup.find_all('article', 'post post_preview')

        if len(posts) == 0:
            break
        results += posts
        index += 1
        time.sleep(0.2)

    return results

preview_posts = get_habr_preview_posts()

# %%
def get_habr_posts(preview_posts: ResultSet) -> {str: Tag}:
    '''
    Getting full posts.

    :return: a dictionary with url and article data
    '''
    posts = dict()
    
    for post in preview_posts:
        post_title_link: Tag = post.find('a', class_='post__title_link')
        url = post_title_link.get('href')
        response = request('GET', url)
        soup = BeautifulSoup(response.text)
        find_result = soup.find_all('div', class_='content_left js-content_left')

        posts.setdefault(url, find_result[0])

    return posts

posts = get_habr_posts(preview_posts)

# %%
len(posts)
# Out:
# 997

# %%
def filter_posts(
        dict_posts: {str: Tag},
        filter_words: [str]
) -> {str: ResultSet}:
    '''
    Filters articles by text considering filter_words
    '''
    result = dict()
    attribute_names = [
        'post__text post__text-html post__text_v1',
        'post__text post__text-html post__text_v2',
        'post__text post__text-html post__text_v3',
        'post__text post__text-html post__text_v4'
    ]
    for url in dict_posts:
        tag = None

        post: ResultSet = dict_posts[url]

        for name in attribute_names:
            tag = post .find('div', attrs={'class': name})

            if not tag is None:
                break

        if tag is None:
            continue

        for filter_word in filter_words:
            if not filter_word.lower() in tag.text.lower():
                continue
            result.setdefault(url, post)
            break
    return result

def transform_to_dataframe(posts: {str: Tag}) -> pandas.DataFrame:
    urls = []
    headers =[]
    date = []

    for url in posts:
        tag: Tag = posts[url].find('span', class_='post__title-text')
        time: Tag = posts[url].find('span', class_='post__time')

        headers.append(tag.text)
        urls.append(url)
        date.append(time.attrs['data-time_published'])

    return pandas.DataFrame({
        'date': date,
        'header': headers,
        'url': urls
    })

filter_habr_posts = filter_posts(
    dict_posts=posts,
    filter_words=['python', 'парсинг']
)
dataFrame = transform_to_dataframe(filter_habr_posts)

dataFrame
# Out:
#                  date                                             header  \
# 0   2021-03-26T15:21Z  Поддержка токенов PKCS#11 с ГОСТ-криптографией...
# 1   2021-03-26T10:50Z  Google Earth Engine (GEE) как общедоступный ка...
# 2   2021-03-26T04:57Z                  Pulsar vs Kafka: сравнение и мифы
# 3   2021-03-24T15:00Z  Работаем с lightsquid или как сделать индивиду...
# 4   2021-03-24T13:24Z  Выводим нейронную сеть в продакшин для Android...
# 5   2021-03-24T10:32Z  Основы работы с Helm чартами и темплейтами — Ч...
# 6   2021-03-24T08:23Z  Полное руководство по созданию Docker-образа д...
# 7   2021-03-23T14:19Z        Зачем мы транспилируем Haskell в JavaScript
# 8   2021-03-22T23:01Z  CosmicPi: обнаружение космического излучения п...
# 9   2021-03-22T18:41Z  Привычный ужас в SIP, или о том, как не надо п...
# 10  2021-03-22T15:48Z          Security Week 12: стеганография в Twitter
# 11  2021-03-22T14:55Z                           Галопом по основам Regex
# 12  2021-03-22T13:10Z                              Как обойти капчу Гугл
# 13  2021-03-22T06:39Z         Решение Fizzbuzz при помощи теоремы Эйлера
# 14  2021-03-21T18:00Z  FOSS News №61 – дайджест материалов о свободно...
# 15  2021-03-21T07:56Z  Устройство поисковых систем: базовый поиск и и...
# 16  2021-03-20T09:01Z  YouTube-проигрыватель сверхвысокого разрешения...
# 17  2021-03-19T17:28Z  25 актуальных вопросов работодателю + коммента...
# 18  2021-03-19T11:34Z                Pattern matching. Теперь и в Python
# 19  2021-03-19T09:20Z  Однажды Microsoft забанила всю мою страну за ч...
# 20  2021-03-18T14:08Z  Поддержка токенов PKCS#11 с ГОСТ-криптографией...
# 21  2021-03-18T09:05Z           Создание образа Мона Лизы в Игре «Жизнь»
# 22  2021-03-17T15:10Z  Добавляем modbus в Embox RTOS и используем на ...
# 23  2021-03-17T14:57Z  8 команд для Python по работе с файлами и файл...
# 24  2021-03-16T14:21Z  Обзор Adafruit Feather RP2040: как Raspberry P...
# 25  2021-03-16T13:38Z  Sourcetrail: инструмент, чтобы разобраться в ч...
# 26  2021-03-16T10:37Z  JavaScript prototype pollution: практика поиск...
# 27  2021-03-16T09:41Z                       Энтерпрайз разработка с нуля
# 28  2021-03-16T08:44Z        Прочти меня: код, который не выбесит соседа
# 29  2021-03-16T08:12Z  Большой разговор с новым Kotlin Project Lead Р...
# 30  2021-03-16T07:47Z  Интервью с Андреем Дудиным, Head of Infrastruc...
# 31  2021-03-15T17:12Z  Elasticsearch: сайзинг шардов как завещал Elas...
# 32  2021-03-15T15:20Z  Символы Unicode: о чём должен знать каждый раз...
# 33  2021-03-15T13:43Z    PHP Дайджест № 200 (22 февраля – 15 марта 2021)
# 34  2021-03-15T13:30Z  Мобильное настоящее «М.Видео»: телепортация бы...
# 35  2021-03-15T09:11Z   Геология XXI века: от реальности к виртуальности
# 36  2021-03-15T00:42Z  ossh: параллельное выполнение команд на многих...
# 37  2021-03-14T16:54Z  FOSS News №60 – дайджест материалов о свободно...
# 38  2021-03-14T16:01Z  Дайджест интересных материалов для мобильного ...
# 39  2021-03-13T13:01Z             Взрослый разговор о пентесте и хакинге
# 40  2021-03-13T09:17Z  Вышел релиз GitLab 13.9 с панелью оповещений б...
# 41  2021-03-13T04:23Z  Вычислительная геология и визуализация: пример...
# 42  2021-03-12T12:45Z  [Личный опыт] Вжух — и ты в биотехе. Как устро...
# 43  2021-03-12T09:09Z  Трепещущий Kivy. Обзор возможностей фреймворка...
# 44  2021-03-10T22:37Z  Оживление портрета с помощью Realistic Neural ...
# 45  2021-03-10T15:47Z  Проигрыватель для очень медленного воспроизвед...
#
#                                                   url
# 0                    https://habr.com/ru/post/549198/
# 1                    https://habr.com/ru/post/549142/
# 2   https://habr.com/ru/company/southbridge/blog/5...
# 3                    https://habr.com/ru/post/548782/
# 4                    https://habr.com/ru/post/467055/
# 5                    https://habr.com/ru/post/548720/
# 6     https://habr.com/ru/company/mailru/blog/548480/
# 7   https://habr.com/ru/company/typeable/blog/548574/
# 8   https://habr.com/ru/company/selectel/blog/547872/
# 9                    https://habr.com/ru/post/543782/
# 10  https://habr.com/ru/company/kaspersky/blog/548...
# 11                   https://habr.com/ru/post/548368/
# 12                   https://habr.com/ru/post/478578/
# 13                   https://habr.com/ru/post/547892/
# 14                   https://habr.com/ru/post/548194/
# 15                   https://habr.com/ru/post/545634/
# 16     https://habr.com/ru/company/ruvds/blog/546976/
# 17       https://habr.com/ru/company/gms/blog/548016/
# 18  https://habr.com/ru/company/yandex_praktikum/b...
# 19    https://habr.com/ru/company/vdsina/blog/547736/
# 20                   https://habr.com/ru/post/547770/
# 21     https://habr.com/ru/company/ruvds/blog/546920/
# 22     https://habr.com/ru/company/embox/blog/547582/
# 23  https://habr.com/ru/company/selectel/blog/547290/
# 24  https://habr.com/ru/company/selectel/blog/547288/
# 25     https://habr.com/ru/company/ruvds/blog/547322/
# 26    https://habr.com/ru/company/huawei/blog/547178/
# 27       https://habr.com/ru/company/nsd/blog/526380/
# 28    https://habr.com/ru/company/yandex/blog/545224/
# 29     https://habr.com/ru/company/jugru/blog/547138/
# 30                   https://habr.com/ru/post/483292/
# 31  https://habr.com/ru/company/galssoftware/blog/...
# 32    https://habr.com/ru/company/mailru/blog/547084/
# 33                   https://habr.com/ru/post/547158/
# 34    https://habr.com/ru/company/mvideo/blog/546474/
# 35                   https://habr.com/ru/post/547068/
# 36                   https://habr.com/ru/post/546998/
# 37                   https://habr.com/ru/post/546988/
# 38  https://habr.com/ru/company/productivity_insid...
# 39     https://habr.com/ru/company/ruvds/blog/546816/
# 40                   https://habr.com/ru/post/546818/
# 41                   https://habr.com/ru/post/546800/
# 42       https://habr.com/ru/company/gms/blog/546728/
# 43                   https://habr.com/ru/post/546684/
# 44                   https://habr.com/ru/post/494678/
# 45     https://habr.com/ru/company/ruvds/blog/546044/
